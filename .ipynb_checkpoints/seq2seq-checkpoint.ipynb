# %% [markdown]
# # SEQ2SEQ implemented as in DILATE (2020)

# %%
# %config IPCompleter.greedy=True

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from tqdm import tqdm

import torch
from torch.utils.data import DataLoader, Dataset
import numpy as np
import random

torch.manual_seed(0)
random.seed(0)
np.random.seed(0)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

from datasets import Traffic, ECG5000, split_dataset
from seq2seq_dilate import EncoderRNN, DecoderRNN, NetGRU, train_model, get_forecasts

from metrics import calc_tdi_tdm, squared_error, absolute_error
from utilities import plot_forecasts, eval_forecasts

# %% [markdown]
# def plot_forecasts(model, test_loader, n):
#     batch_seq, batch_target = next(iter(test_loader))
#     batch_seq, batch_target = batch_seq.type(torch.float32).to(device), batch_target.type(torch.float32).to(device)
#
#     model.eval()
#     batch_forecast = gru_net(batch_seq)
#
#     for i in range(0, n):
#         seq = batch_seq.detach().cpu().numpy()[i, :, :]
#         target = batch_target.detach().cpu().numpy()[i, :, :]
#         forecast = batch_forecast.detach().cpu().numpy()[i, :, :]
#
#         plot_result(seq, target, forecast)
#         print("(TDI, TDM): ", tdi_tdm(target, forecast))
#
# predict_on_batch(gru_net, ecg_test_loader, n=16)

# %% [markdown]
# # Seq2Seq on ECG5000

# %%
# Parameters
window = 84
horizon = 56
batch_size = 10
epochs = 20
lr = 0.01
 
# Load data
ecg_train = ECG5000("./data/ECG5000/ECG5000_TRAIN.tsv", window, horizon)
ecg_test = ECG5000("./data/ECG5000/ECG5000_TEST.tsv", window, horizon)
ecg_train_loader = torch.utils.data.DataLoader(ecg_train, batch_size=batch_size, shuffle=True, drop_last=True)
ecg_test_loader = torch.utils.data.DataLoader(ecg_train, batch_size=batch_size, shuffle=False, drop_last=True)

# Build model
encoder = EncoderRNN(input_size=1, hidden_size=128, num_grulstm_layers=1, batch_size=batch_size).to(device)
decoder = DecoderRNN(input_size=1, hidden_size=128, num_grulstm_layers=1, fc_units=16, output_size=1).to(device)
gru_net = NetGRU(encoder, decoder, horizon, device).to(device)
optimizer = torch.optim.Adam(gru_net.parameters(), lr=lr)
loss_fn = torch.nn.MSELoss()

# Train
train_model(gru_net, optimizer, loss_fn, ecg_train_loader, epochs=epochs)
# Out:
# DILATE GRU: 100%|████████████████████████████████████████████████| 20/20 [02:00<00:00,  6.05s/epoch, train_loss=0.0387]

# %% [markdown]
# Get predictions

# %%
# Get forecasts on test
x_test, y_test, yhat_test = get_forecasts(gru_net, ecg_test_loader)

# Plots
plot_forecasts(x_test, y_test, yhat_test, n=5, shuffle=True)
# Out:
# TDI: 0.05, TDM: 0.32
# TDI: 0.09, TDM: 0.80
# TDI: 0.18, TDM: 0.02
# TDI: 0.05, TDM: 0.69
# TDI: 0.08, TDM: 0.77

# %% [markdown]
# Evaluate forecasts

# %%
# Compute stats
stats, sq_err, abs_err = eval_forecasts(y_test, yhat_test)

# Plot TDI/TDM
fig = plt.figure()
fig.add_subplot(121)
stats["TDI"].plot.hist(title="TDI", bins=50)
fig.add_subplot(122)
stats["TDM"].plot.hist(title="TDM", bins=25)
plt.tight_layout()
plt.show()

# Plot squared errors
sq_err.plot.box(title="Squared errors", figsize=(30,3))
plt.show()

# Plot absolute errors
abs_err.plot.box(title="Absolute errors", figsize=(30,3))
plt.show()

# %% [markdown]
# # Seq2seq on Traffic

# %%
# Parameters
window = 24
horizon = 24
batch_size = 32
epochs = 20
lr = 0.01
 
# Load data
ds = Traffic("./data/mvdata/traffic.txt", 24, 24, usecol=0)
traffic_train, traffic_test = split_dataset(ds, 0.2)
traffic_train_loader = torch.utils.data.DataLoader(traffic_train, batch_size=batch_size, shuffle=True, drop_last=True)
traffic_test_loader = torch.utils.data.DataLoader(traffic_test, batch_size=batch_size, shuffle=True, drop_last=True)

# Build model
encoder = EncoderRNN(input_size=1, hidden_size=128, num_grulstm_layers=1, batch_size=batch_size).to(device)
decoder = DecoderRNN(input_size=1, hidden_size=128, num_grulstm_layers=1, fc_units=16, output_size=1).to(device)
gru_net = NetGRU(encoder, decoder, horizon, device).to(device)
optimizer = torch.optim.Adam(gru_net.parameters(), lr=lr)
loss_fn = torch.nn.MSELoss()

# Train
train_model(gru_net, optimizer, loss_fn, traffic_train_loader, epochs=epochs)
# Out:
# DILATE GRU: 100%|███████████████████████████████████████████████| 20/20 [09:27<00:00, 28.37s/epoch, train_loss=3.21e-5]

# %%
# Get forecasts on test
x_test, y_test, yhat_test = get_forecasts(gru_net, traffic_test_loader)

# Plots
plot_forecasts(x_test, y_test, yhat_test, n=5, shuffle=True)
# Out:
# TDI: 0.11, TDM: -0.42
# TDI: 0.06, TDM: 0.12
# TDI: 0.11, TDM: -0.61
# TDI: 0.03, TDM: 0.20
# TDI: 0.07, TDM: -0.25

# %% [markdown]
# Evaluate forecasts

# %%
# Compute stats
stats, sq_err, abs_err = eval_forecasts(y_test, yhat_test)

# Plot TDI/TDM
fig = plt.figure()
fig.add_subplot(121)
stats["TDI"].plot.hist(title="TDI", bins=50)
fig.add_subplot(122)
stats["TDM"].plot.hist(title="TDM", bins=25)
plt.tight_layout()
plt.show()

# Plot squared errors
sq_err.plot.box(title="Squared errors", figsize=(30,3))
plt.show()

# Plot absolute errors
abs_err.plot.box(title="Absolute errors", figsize=(30,3))
plt.show()
# Out:
# C:\Users\eivistr\Documents\PycharmProjects\TDT4900-masters-thesis\metrics.py:76: RuntimeWarning: invalid value encountered in double_scalars
#   tdi_late = abs(np.trapz(j_l[indices], j_l[indices] - i_l[indices]) / np.trapz(j_l, abs(j_l - i_l)))
