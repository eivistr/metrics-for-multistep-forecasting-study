# %%
# %config IPCompleter.greedy=True

from matplotlib import pyplot as plt
import pandas as pd
from tqdm import tqdm

import numpy as np
import random

import pmdarima as pm
from pmdarima.model_selection import train_test_split

np.random.seed(0)
random.seed(0)

from metrics import tdi_tdm, squared_error, absolute_error

# %%
def plot_result(train, test, forecast, model):
    x = np.arange(train.shape[0] + test.shape[0])
    l = len(train)
    
    fig, axs = plt.subplots(nrows=1, ncols=3)
    axs[0].plot(x[:l], train, c='blue')
    axs[0].plot(x[l:], test, c='red')
    axs[0].plot(x[l:], forecast, c='green')
    axs[0].set_title(f"Series {i}. Best fit: SARIMA{model.to_dict()['order']}{model.to_dict()['seasonal_order']}")
    
    axs[1].plot(x[l:], squared_error(test, forecast))
    axs[1].set_title(f"Squared errors")
    
    axs[2].plot(x[l:], absolute_error(test, forecast))
    axs[2].set_title(f"Absolute errors")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # ARIMA on ECG5000

# %%
# Parameters
n = 10
window = 56
horizon = 84

# Load data
df = pd.read_csv("./data/ECG5000/ECG5000_TRAIN.tsv", delimiter="\t", header=None).drop(0, axis=1).transpose()
df = df.diff().dropna()

for i in range(0, n):
    series = df[i].values
    train, test = train_test_split(series, train_size=window - 1)  # First row was removed by diff()
    
    model = pm.auto_arima(train, suppress_warnings=True, trace=False)
    forecast = model.predict(n_periods=test.shape[0])  # Predict N steps into the future
    
    plot_result(train, test, forecast, model)
    print("(TDI, TDM): ", tdi_tdm(test, forecast))

# %% [markdown]
# # ARIMA on Traffic

# %%
# Parameters
n = 10
window = 24*7
horizon = 24*3

df = pd.read_csv("./data/mvdata/traffic.txt", usecols=range(0, n), header=None)

for i in range(0, n):
    series = df[i].values[-window-horizon:]
    train, test = train_test_split(series, train_size=window)
    
    model = pm.auto_arima(train, seasonal=True, m=24, suppress_warnings=True, trace=True)
    forecast = model.predict(n_periods=test.shape[0])  # Predict N steps into the future
    
    plot_result(train, test, forecast, model)
    print("(TDI, TDM): ", tdi_tdm(test, forecast))
# Out:
# (TDI, TDM):  (0.04263117283950617, -0.7194570135746606)
# (TDI, TDM):  (0.06732253086419752, -0.20916905444126077)
# (TDI, TDM):  (0.043209876543209874, 0.08928571428571419)
# (TDI, TDM):  (0.05825617283950617, 0.21192052980132448)
# (TDI, TDM):  (0.0630787037037037, -0.6146788990825688)
# (TDI, TDM):  (0.07118055555555555, -0.6043360433604337)
# (TDI, TDM):  (0.07388117283950617, -0.2323759791122716)
# (TDI, TDM):  (0.03337191358024691, 0.17919075144508678)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-44-6568d0a18cef> in <module>
#      10     train, test = train_test_split(series, train_size=window)
#      11
# ---> 12     model = pm.auto_arima(train, seasonal=True, m=24, suppress_warnings=True, trace=False)
#      13     forecast = model.predict(n_periods=test.shape[0])  # Predict N steps into the future
#      14
#
# ...
