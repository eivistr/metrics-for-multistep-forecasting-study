# %%
# %config IPCompleter.greedy=True

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import pickle
import random

import torch
from torch.utils.data import DataLoader

from evaluation import Result, Evaluation
from datasets import get_dataset

# %% [markdown]
# # Traffic

# %%
res_traffic = pickle.load(open('./results/traffic_test.pickle', "rb"))

# %% [markdown]
# # TCN

# %%
traffic0 = Evaluation(res_traffic[0])

print(traffic0)
traffic0.plot_forecasts()
traffic0.plot_metrics()
# Out:
# Evaluation of TCN on dataset traffic, a total of 192 24-step ahead forecasts.

# %% [markdown]
# # S2S GRU

# %%
traffic1 = Evaluation(res_traffic[1])

print(traffic1)
traffic1.plot_forecasts()
traffic1.plot_metrics()
# Out:
# Evaluation of GRU on dataset traffic, a total of 192 24-step ahead forecasts.

# %% [markdown]
# # S2S LSTM

# %%
traffic2 = Evaluation(res_traffic[2])

print(traffic2)
traffic2.plot_forecasts()
traffic2.plot_metrics()
# Out:
# Evaluation of LSTM on dataset traffic, a total of 192 24-step ahead forecasts.

# %% [markdown]
# # ARIMA

# %%
traffic3 = Evaluation(res_traffic[3])

print(traffic3)
traffic3.plot_forecasts()
traffic3.plot_metrics()
# Out:
# Evaluation of ARIMA on dataset traffic, a total of 192 24-step ahead forecasts.
